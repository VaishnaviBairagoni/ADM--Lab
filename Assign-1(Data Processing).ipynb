# %% [markdown]
# <a href="https://colab.research.google.com/github/VaishnaviBairagoni/Data-Mining/blob/main/Assign-1(Data%20Processing).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Load a Dataset (CSV/Excel/JSON) using Pandas

import pandas as pd
data=pd.read_csv('/content/sample_data/titanic.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#2. Handle Missing Values (Mean, Median, or Mode Imputation)

# Check for missing values
print(data.isnull().sum())
#Impute missing values with mean (for numerical columns)
data['Age'].fillna(data['Age'].mean())

# Alternatively, you can impute with the median
data['Age'].fillna(data['Age'].median())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64
# 0     -5.924806e-01
# 1      6.387890e-01
# 2     -2.846632e-01
# 3      4.079260e-01
# 4      4.079260e-01
#            ...
# 886   -2.077088e-01
# 887   -8.233437e-01
# 888   -3.399518e-16
# 889   -2.846632e-01
# 890    1.770629e-01
# Name: Age, Length: 891, dtype: float64

# %%
#3. Feature Scaling (Min-Max Normalization or Standardization

from sklearn.preprocessing import MinMaxScaler

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Select columns to normalize (numerical columns)
columns_to_normalize = ['Age', 'Fare']

# Apply Min-Max normalization
data[columns_to_normalize] =scaler.fit_transform(data[columns_to_normalize])

# Display the first few rows after normalization
data[columns_to_normalize].head()
# Out:
#         Age      Fare
# 0  0.271174  0.014151
# 1  0.472229  0.139136
# 2  0.321438  0.015469
# 3  0.434531  0.103644
# 4  0.434531  0.015713

# %%
#Standardization (Z-Score Normalization)

from sklearn.preprocessing import StandardScaler

# Initialize StandardScaler
scaler = StandardScaler()

# Apply standardization to numerical columns
data[columns_to_normalize] =scaler.fit_transform(data[columns_to_normalize])

# Display the first few rows after standardization
data[columns_to_normalize].head()
# Out:
#         Age      Fare
# 0 -0.592481 -0.502445
# 1  0.638789  0.786845
# 2 -0.284663 -0.488854
# 3  0.407926  0.420730
# 4  0.407926 -0.486337
